# %%
# Import libraries
import os

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
# Read News and DJIA Data
df_news = pd.read_csv(os.path.join('..', 'data', 'RedditNews.csv'))
df_stock = pd.read_csv(os.path.join('..', 'data', 'upload_DJIA_table.csv'))

# %%
df_stock.tail()
# Out:
#             Date          Open          High           Low         Close  \
# 1984  2008-08-14  11532.070312  11718.280273  11450.889648  11615.929688
# 1985  2008-08-13  11632.809570  11633.780273  11453.339844  11532.959961
# 1986  2008-08-12  11781.700195  11782.349609  11601.519531  11642.469727
# 1987  2008-08-11  11729.669922  11867.110352  11675.530273  11782.349609
# 1988  2008-08-08  11432.089844  11759.959961  11388.040039  11734.320312
#
#          Volume     Adj Close
# 1984  159790000  11615.929688
# 1985  182550000  11532.959961
# 1986  173590000  11642.469727
# 1987  183190000  11782.349609
# 1988  212830000  11734.320312

# %%
# check data
display(df_news.info())
display(df_stock.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73608 entries, 0 to 73607
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    73608 non-null  object
#  1   News    73608 non-null  object
# dtypes: object(2)
# memory usage: 1.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1989 entries, 0 to 1988
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1989 non-null   object
#  1   Open       1989 non-null   float64
#  2   High       1989 non-null   float64
#  3   Low        1989 non-null   float64
#  4   Close      1989 non-null   float64
#  5   Volume     1989 non-null   int64
#  6   Adj Close  1989 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 108.9+ KB
# None

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
import re

# Initialize the lemmatizer
lemmatizer = WordNetLemmatizer()

# Define the stop words
stop_words = set(stopwords.words('english'))

# Define a function to preprocess the headlines
def preprocess_text(text):
    # Convert the text to lower case
    text = text.lower()
    
    text = re.sub(r"b'",'', text)
    
    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)
    
    # Tokenize the text
    text = text.split()
    
    # Remove stop words and lemmatize the words
    text = [lemmatizer.lemmatize(word) for word in text if word not in stop_words]
    
    # Join the words back into a single string
    text = ' '.join(text)
    
    return text

# Apply the function to the headlines
df_news['News_Preprocessed'] = df_news['News'].apply(preprocess_text)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\duzzi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\duzzi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\duzzi\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
df_stock.sort_values(by='Date',inplace=True)

# %%
# Convert prices to returns
df_stock.sort_values(by='Date',inplace=True)
df_stock['returns'] = df_stock['Adj Close'].pct_change()

# Drop the first row, which will have a missing return
df_stock = df_stock.dropna()

# %%
import matplotlib.pyplot as plt

# Plot the actual and predicted returns
plt.figure(figsize=(14, 5))
plt.plot(df_stock['returns'], color='blue', label='Actual returns')
plt.title('Stock returns prediction')
plt.xlabel('Time')
plt.ylabel('Normalized stock returns')
plt.legend()
plt.show()

# %% [markdown]
# ## Sentiment Analysis

# %% [markdown]
# ### Vader Score

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\duzzi\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# Initialize the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Define a function to calculate sentiment scores
def get_sentiment(text):
    # Calculate the sentiment scores
    sentiment = analyzer.polarity_scores(text)
    
    # Return the compound score
    return sentiment['compound']

# Apply the function to the headlines
df_news['sentiment_vader'] = df_news['News_Preprocessed'].apply(get_sentiment)

# %%
from textblob import TextBlob

def get_sentiment_Blob(text):
    # Create a TextBlob object
    blob = TextBlob(text)
    
    # Get the sentiment
    sentiment = blob.sentiment
    
    # Return the compound score
    return sentiment[0]

# Apply the function to the headlines
df_news['sentiment_blob'] = df_news['News_Preprocessed'].apply(get_sentiment_Blob)

# %%
pip install flair
# Out:
# Collecting flair
#   Downloading flair-0.12.2-py3-none-any.whl (373 kB)
kB 991.0 kB/s eta 0:00:01
#      -------------------------------------- 67.1/67.1 kB 903.0 kB/s eta 0:00:00
# Requirement already satisfied: zipp>=3.1.0 in c:\users\duzzi\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=2.2.3->flair) (3.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\duzzi\anaconda3\lib\site-packages (from requests[socks]->gdown==4.4.0->flair) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\duzzi\anaconda3\lib\site-packages (from requests[socks]->gdown==4.4.0->flair) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\duzzi\anaconda3\lib\site-packages (from requests[socks]->gdown==4.4.0->flair) (2023.5.7)
# Collecting accelerate>=0.20.3 (from transformers[sentencepiece]>=4.18.0->flair)
#   Downloading accelerate-0.21.0-py3-none-any.whl (244 kB)
#                                               0.0/244.2 kB ? eta -:--:--
#      ----                                    30.7/244.2 kB 1.3 MB/s eta 0:00:01
#      ---------                             61.4/244.2 kB 812.7 kB/s eta 0:00:01
#      -------------                         92.2/244.2 kB 871.5 kB/s eta 0:00:01
#      ---------------------                143.4/244.2 kB 847.9 kB/s eta 0:00:01
#      -------------------------            174.1/244.2 kB 803.1 kB/s eta 0:00:01
#      ---------------------------------    225.3/244.2 kB 808.4 kB/s eta 0:00:01
#      ------------------------------------ 244.2/244.2 kB 787.6 kB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in c:\users\duzzi\anaconda3\lib\site-packages (from beautifulsoup4->gdown==4.4.0->flair) (2.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\duzzi\anaconda3\lib\site-packages (from jinja2->torch!=1.8,>=1.5.0->flair) (2.0.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\duzzi\anaconda3\lib\site-packages (from requests[socks]->gdown==4.4.0->flair) (1.7.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\duzzi\anaconda3\lib\site-packages (from sympy->torch!=1.8,>=1.5.0->flair) (1.2.1)
# Requirement already satisfied: psutil in c:\users\duzzi\anaconda3\lib\site-packages (from accelerate>=0.20.3->transformers[sentencepiece]>=4.18.0->flair) (5.9.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\duzzi\anaconda3\lib\site-packages (from aiohttp->datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair) (22.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair)
#   Downloading multidict-6.0.4-cp38-cp38-win_amd64.whl (28 kB)
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair)
#   Downloading yarl-1.9.2-cp38-cp38-win_amd64.whl (61 kB)
#                                               0.0/61.8 kB ? eta -:--:--
#      -------------------------              41.0/61.8 kB 653.6 kB/s eta 0:00:01
#      -------------------------------------- 61.8/61.8 kB 660.8 kB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair)
#   Downloading frozenlist-1.4.0-cp38-cp38-win_amd64.whl (44 kB)
#                                               0.0/44.7 kB ? eta -:--:--
#      -------------------------------------- 44.7/44.7 kB 733.4 kB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\duzzi\anaconda3\lib\site-packages (from pandas->datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair) (2022.6)
# Collecting simpful (from pyfume->FuzzyTM>=0.4.0->gensim>=3.8.0->flair)
#   Downloading simpful-2.11.0-py3-none-any.whl (32 kB)
# Collecting fst-pso (from pyfume->FuzzyTM>=0.4.0->gensim>=3.8.0->flair)
#   Downloading fst-pso-1.8.1.tar.gz (18 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting miniful (from fst-pso->pyfume->FuzzyTM>=0.4.0->gensim>=3.8.0->flair)
#   Downloading miniful-0.0.6.tar.gz (2.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: gdown, mpld3, sqlitedict, langdetect, pptree, fst-pso, miniful
#   Building wheel for gdown (pyproject.toml): started
#   Building wheel for gdown (pyproject.toml): finished with status 'done'
#   Created wheel for gdown: filename=gdown-4.4.0-py3-none-any.whl size=14786 sha256=6fad367569e0823e6f095b5c2e7502b3fee5c7679d6d58abdc84a642420ec324
#   Stored in directory: c:\users\duzzi\appdata\local\pip\cache\wheels\7b\7b\5d\656f46cd6889e4c93977be9586901d0adc1271b2d876c84c96
#   Building wheel for mpld3 (setup.py): started
#   Building wheel for mpld3 (setup.py): finished with status 'done'
#   Created wheel for mpld3: filename=mpld3-0.3-py3-none-any.whl size=116718 sha256=a48f5aee48c42c4f3cefe1f88df91fb9b99a2b0118d52bf8ffc32291a7257b43
#   Stored in directory: c:\users\duzzi\appdata\local\pip\cache\wheels\3d\9f\9d\d806a20bd97bc7076d724fa3e69fa5be61836ba16b2ffa6126
#   Building wheel for sqlitedict (setup.py): started
#   Building wheel for sqlitedict (setup.py): finished with status 'done'
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16901 sha256=ab4eaff0c134844dc30649f14a093e295962c3afbef85eddc6f698138341330e
#   Stored in directory: c:\users\duzzi\appdata\local\pip\cache\wheels\04\c6\16\46e174009277f9bccdaa7215a243939d2f70180804b249bf3a
#   Building wheel for langdetect (setup.py): started
#   Building wheel for langdetect (setup.py): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993253 sha256=da8bfe201a0f69dc76ab86784f03bc736984233f49f24a0e756a5b1d431b4acc
#   Stored in directory: c:\users\duzzi\appdata\local\pip\cache\wheels\13\c7\b0\79f66658626032e78fc1a83103690ef6797d551cb22e56e734
#   Building wheel for pptree (setup.py): started
#   Building wheel for pptree (setup.py): finished with status 'done'
#   Created wheel for pptree: filename=pptree-3.1-py3-none-any.whl size=4613 sha256=5d1c0a47be62a2607ca879937b7778b6d7d760e1b1b2ebdbe7860103af66a4c0
#   Stored in directory: c:\users\duzzi\appdata\local\pip\cache\wheels\e1\8b\30\5b20240d3d13a9dfafb6a6dd49d1b541c86d39812cb3690edf
#   Building wheel for fst-pso (setup.py): started
#   Building wheel for fst-pso (setup.py): finished with status 'done'
#   Created wheel for fst-pso: filename=fst_pso-1.8.1-py3-none-any.whl size=20448 sha256=45ab9c0dbd833ddf4948159f6f919f5babf2fb169a66153d193f2a54e68fea3e
#   Stored in directory: c:\users\duzzi\appdata\local\pip\cache\wheels\6a\65\c4\d27eeee9ba3fc150a0dae150519591103b9e0dbffde3ae77dc
#   Building wheel for miniful (setup.py): started
#   Building wheel for miniful (setup.py): finished with status 'done'
#   Created wheel for miniful: filename=miniful-0.0.6-py3-none-any.whl size=3522 sha256=d737259cde6b9dbd39f4f4c8340041e1267125b19f196603d1fbcf8c65cd2af6
#   Stored in directory: c:\users\duzzi\appdata\local\pip\cache\wheels\ba\d9\a0\ddd93af16d5855dd9bad417623e70948fdac119d1d34fb17c8
# Successfully built gdown mpld3 sqlitedict langdetect pptree fst-pso miniful
# Installing collected packages: tokenizers, sqlitedict, sentencepiece, safetensors, py4j, pptree, mpld3, janome, xxhash, segtok, pyarrow, multiprocess, multidict, langdetect, ftfy, frozenlist, deprecated, conllu, async-timeout, yarl, wikipedia-api, torch, simpful, miniful, hyperopt, huggingface-hub, aiosignal, transformers, pytorch-revgrad, gdown, fst-pso, aiohttp, accelerate, pyfume, FuzzyTM, datasets, transformer-smaller-training-vocab, bpemb, flair
# Successfully installed FuzzyTM-2.0.5 accelerate-0.21.0 aiohttp-3.8.5 aiosignal-1.3.1 async-timeout-4.0.2 bpemb-0.3.4 conllu-4.5.3 datasets-2.13.1 deprecated-1.2.14 flair-0.12.2 frozenlist-1.4.0 fst-pso-1.8.1 ftfy-6.1.1 gdown-4.4.0 huggingface-hub-0.16.4 hyperopt-0.2.7 janome-0.5.0 langdetect-1.0.9 miniful-0.0.6 mpld3-0.3 multidict-6.0.4 multiprocess-0.70.14 pptree-3.1 py4j-0.10.9.7 pyarrow-12.0.1 pyfume-0.2.25 pytorch-revgrad-0.2.0 safetensors-0.3.1 segtok-1.5.11 sentencepiece-0.1.99 simpful-2.11.0 sqlitedict-2.1.0 tokenizers-0.13.3 torch-2.0.1 transformer-smaller-training-vocab-0.2.4 transformers-4.31.0 wikipedia-api-0.6.0 xxhash-3.2.0 yarl-1.9.2

# %%
from flair.models import TextClassifier
from flair.data import Sentence

# Load the sentiment classifier
classifier = TextClassifier.load('en-sentiment')

# Create a sentence
sentence = Sentence('Flair sentiment analysis is ok!')

# Predict the sentiment
classifier.predict(sentence)

print(sentence.labels)
sentence.score
# Out:
# ['Sentence[6]: "Flair sentiment analysis is ok!"'/'POSITIVE' (0.6555)]
# 0.6555489897727966

# %%
sentence.score
# Out:
# 0.6555489897727966

# %% [markdown]
# ### FinBert

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
from torch.nn import Softmax

# Check if a GPU is available and if not, use a CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load pre-trained model and tokenizer (FinBERT from ProsusAI)
tokenizer = AutoTokenizer.from_pretrained("ProsusAI/finbert")
model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert")

# Move the model to the GPU if one is available
model = model.to(device)

# Put model in evaluation mode
model.eval()

# Convert inputs to PyTorch tensors
text = "Apple is ok."

def get_sentiment_FinBert(text):
    inputs = tokenizer(text, return_tensors="pt")
    
    # Move the inputs to the GPU if one is available
    inputs = inputs.to(device)

    # Predict the sentiment
    with torch.no_grad():
        outputs = model(**inputs)

    # Apply softmax to the output to get probabilities
    probs = Softmax(dim=1)(outputs.logits)
    
    # Move probs to cpu
    probs = probs.cpu()
    
    # Convert tensor to list and return separate values
    probs = probs[0].tolist()
    return probs[0], probs[1], probs[2]

# Apply the function to the headlines
df_news['sentiment_FinBert_positiv'],df_news['sentiment_FinBert_negative'],df_news['sentiment_FinBert_neutral'] = df_news['News'].apply(get_sentiment_FinBert)
# get_sentiment_FinBert(text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 42
#      39     return probs[0], probs[1], probs[2]
#      41 # Apply the function to the headlines
# ---> 42 df_news['sentiment_FinBert_positiv'],df_news['sentiment_FinBert_negative'],df_news['sentiment_FinBert_neutral'] = df_news['News'].apply(get_sentiment_FinBert)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\apply.py:1105, in SeriesApply.apply(self)
#    1102     return self.apply_str()
#    1104 # self.f is Callable
# -> 1105 return self.apply_standard()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\apply.py:1156, in SeriesApply.apply_standard(self)
#    1154     else:
#    1155         values = obj.astype(object)._values
# -> 1156         mapped = lib.map_infer(
#    1157             values,
#    1158             f,
#    1159             convert=self.convert_dtype,
#    1160         )
#    1162 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1163     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1164     #  See also GH#25959 regarding EA support
#    1165     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\_libs\lib.pyx:2918, in pandas._libs.lib.map_infer()
#
# Cell In[32], line 29, in get_sentiment_FinBert(text)
#      27 # Predict the sentiment
#      28 with torch.no_grad():
# ---> 29     outputs = model(**inputs)
#      31 # Apply softmax to the output to get probabilities
#      32 probs = Softmax(dim=1)(outputs.logits)
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\bert\modeling_bert.py:1562, in BertForSequenceClassification.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1554 r"""
#    1555 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#    1556     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#    1557     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#    1558     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#    1559 """
#    1560 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1562 outputs = self.bert(
#    1563     input_ids,
#    1564     attention_mask=attention_mask,
#    1565     token_type_ids=token_type_ids,
#    1566     position_ids=position_ids,
#    1567     head_mask=head_mask,
#    1568     inputs_embeds=inputs_embeds,
#    1569     output_attentions=output_attentions,
#    1570     output_hidden_states=output_hidden_states,
#    1571     return_dict=return_dict,
#    1572 )
#    1574 pooled_output = outputs[1]
#    1576 pooled_output = self.dropout(pooled_output)
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\bert\modeling_bert.py:1022, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1013 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#    1015 embedding_output = self.embeddings(
#    1016     input_ids=input_ids,
#    1017     position_ids=position_ids,
#    (...)
#    1020     past_key_values_length=past_key_values_length,
#    1021 )
# -> 1022 encoder_outputs = self.encoder(
#    1023     embedding_output,
#    1024     attention_mask=extended_attention_mask,
#    1025     head_mask=head_mask,
#    1026     encoder_hidden_states=encoder_hidden_states,
#    1027     encoder_attention_mask=encoder_extended_attention_mask,
#    1028     past_key_values=past_key_values,
#    1029     use_cache=use_cache,
#    1030     output_attentions=output_attentions,
#    1031     output_hidden_states=output_hidden_states,
#    1032     return_dict=return_dict,
#    1033 )
#    1034 sequence_output = encoder_outputs[0]
#    1035 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\bert\modeling_bert.py:612, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     603     layer_outputs = torch.utils.checkpoint.checkpoint(
#     604         create_custom_forward(layer_module),
#     605         hidden_states,
#    (...)
#     609         encoder_attention_mask,
#     610     )
#     611 else:
# --> 612     layer_outputs = layer_module(
#     613         hidden_states,
#     614         attention_mask,
#     615         layer_head_mask,
#     616         encoder_hidden_states,
#     617         encoder_attention_mask,
#     618         past_key_value,
#     619         output_attentions,
#     620     )
#     622 hidden_states = layer_outputs[0]
#     623 if use_cache:
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\bert\modeling_bert.py:539, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     536     cross_attn_present_key_value = cross_attention_outputs[-1]
#     537     present_key_value = present_key_value + cross_attn_present_key_value
# --> 539 layer_output = apply_chunking_to_forward(
#     540     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     541 )
#     542 outputs = (layer_output,) + outputs
#     544 # if decoder, return the attn key/values as the last output
#
# File ~\anaconda3\lib\site-packages\transformers\pytorch_utils.py:239, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     236     # concatenate output at same dimension
#     237     return torch.cat(output_chunks, dim=chunk_dim)
# --> 239 return forward_fn(*input_tensors)
#
# File ~\anaconda3\lib\site-packages\transformers\models\bert\modeling_bert.py:552, in BertLayer.feed_forward_chunk(self, attention_output)
#     550 def feed_forward_chunk(self, attention_output):
#     551     intermediate_output = self.intermediate(attention_output)
# --> 552     layer_output = self.output(intermediate_output, attention_output)
#     553     return layer_output
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\bert\modeling_bert.py:464, in BertOutput.forward(self, hidden_states, input_tensor)
#     463 def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 464     hidden_states = self.dense(hidden_states)
#     465     hidden_states = self.dropout(hidden_states)
#     466     hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
# Calculate the mean sentiment score for each stock for each day
df = df_news.groupby('Date') \
       .agg({'sentiment':'mean',
            'sentiment_blob':'mean',
            'sentiment_FinBert_positiv':'mean',
            'sentiment_FinBert_negative':'mean',
            'sentiment_FinBert_neutral':'mean'}) \
       .rename(columns={'sentiment_vader':'sentiment_vader', 
                        'sentiment_blob':'sentiment_blob',
                        'sentiment_FinBert_positiv':'sentiment_FinBert_positiv',
                        'sentiment_FinBert_negative':'sentiment_FinBert_negative',
                        'sentiment_FinBert_neutral':'sentiment_FinBert_neutral'}) \
       .reset_index()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2943 entries, 0 to 2942
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 2943 non-null   object
#  1   mean_sentiment       2943 non-null   float64
#  2   mean_sentiment_blob  2943 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 69.1+ KB

# %%
df = df.merge(df_stock[['Date', 'returns']], on='Date')

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
# set the index
df.set_index('Date', inplace=True)

# %%
# Calculate the index to split the data
split_idx = int(len(df) * 0.8)

# Split the data into training and testing sets
train = df.iloc[:split_idx]
test = df.iloc[split_idx:]

# %%
test
# Out:
#             mean_sentiment  mean_sentiment_blob    return
# Date
# 2014-12-03       -0.283136             0.031537  0.001850
# 2014-12-04       -0.366076            -0.097358 -0.000699
# 2014-12-05       -0.207776             0.021823  0.003279
# 2014-12-08       -0.254348            -0.022987 -0.005920
# 2014-12-09       -0.210332            -0.018333 -0.002872
# ...                    ...                  ...       ...
# 2016-06-27       -0.131636             0.003040 -0.014971
# 2016-06-28       -0.036128             0.021832  0.015722
# 2016-06-29       -0.181044             0.041622  0.016368
# 2016-06-30       -0.291800             0.015214  0.013298
# 2016-07-01       -0.384692             0.036553  0.001081
#
# [398 rows x 3 columns]

# %%
import numpy as np

# Define the number of timesteps
timesteps = 60

# Define a function to prepare the data for the LSTM
def prepare_data(data, timesteps):
    X = []
    y = []
    
    for i in range(timesteps, len(data)):
        X.append(data[i-timesteps:i])
        y.append(data[i, -1])
    
    return np.array(X), np.array(y)

# Prepare the training and testing data
X_train, y_train = prepare_data(train[['mean_sentiment_blob', return]], timesteps)
X_test, y_test = prepare_data(test.values, timesteps)

# Reshape the data to the format required by the LSTM
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 2))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 22
#      19 X_test, y_test = prepare_data(test.values, timesteps)
#      21 # Reshape the data to the format required by the LSTM
# ---> 22 X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 2))
#      23 X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 2))
#
# File <__array_function__ internals>:180, in reshape(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:298, in reshape(a, newshape, order)
#     198 @array_function_dispatch(_reshape_dispatcher)
#     199 def reshape(a, newshape, order='C'):
#     200     """
#     201     Gives a new shape to an array without changing its data.
#     202
#    (...)
#     296            [5, 6]])
#     297     """
# --> 298     return _wrapfunc(a, 'reshape', newshape, order=order)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# ValueError: cannot reshape array of size 275400 into shape (1530,60,2)

# %% [markdown]
#  ## LSTM model

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense

# Initialize the model
model = Sequential()

# Add the LSTM layer
model.add(LSTM(units=50, return_sequences=False, input_shape=(X_train.shape[1], 2)))

# Add the output layer
model.add(Dense(units=1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 48/48 [==============================] - 3s 26ms/step - loss: 1.6854e-04
# Epoch 2/100
# 48/48 [==============================] - 1s 26ms/step - loss: 1.4331e-04
# Epoch 3/100
# 48/48 [==============================] - 1s 28ms/step - loss: 1.4319e-04
# Epoch 4/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.3876e-04
# Epoch 5/100
# 48/48 [==============================] - 1s 23ms/step - loss: 1.4487e-04
# Epoch 6/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.3681e-04
# Epoch 7/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.4464e-04
# Epoch 8/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.4271e-04
# Epoch 9/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3808e-04
# Epoch 10/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.4187e-04
# Epoch 11/100
# 48/48 [==============================] - 1s 29ms/step - loss: 1.3702e-04
# Epoch 12/100
# 48/48 [==============================] - 1s 28ms/step - loss: 1.4081e-04
# Epoch 13/100
# 48/48 [==============================] - 1s 28ms/step - loss: 1.4014e-04
# Epoch 14/100
# 48/48 [==============================] - 1s 29ms/step - loss: 1.4440e-04
# Epoch 15/100
# 48/48 [==============================] - 1s 27ms/step - loss: 1.4030e-04
# Epoch 16/100
# 48/48 [==============================] - 1s 27ms/step - loss: 1.4041e-04
# Epoch 17/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3738e-04
# Epoch 18/100
# 48/48 [==============================] - 1s 29ms/step - loss: 1.3965e-04
# Epoch 19/100
# 48/48 [==============================] - 1s 27ms/step - loss: 1.3747e-04
# Epoch 20/100
# 48/48 [==============================] - 1s 26ms/step - loss: 1.3696e-04
# Epoch 21/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.3564e-04
# Epoch 22/100
# 48/48 [==============================] - 1s 26ms/step - loss: 1.3883e-04
# Epoch 23/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.4811e-04
# Epoch 24/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.3632e-04
# Epoch 25/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.4279e-04
# Epoch 26/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3784e-04
# Epoch 27/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.4260e-04
# Epoch 28/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3908e-04
# Epoch 29/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3951e-04
# Epoch 30/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.3558e-04
# Epoch 31/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.3638e-04
# Epoch 32/100
# 48/48 [==============================] - 1s 27ms/step - loss: 1.3421e-04
# Epoch 33/100
# 48/48 [==============================] - 1s 26ms/step - loss: 1.3644e-04
# Epoch 34/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.3853e-04
# Epoch 35/100
# 48/48 [==============================] - 1s 26ms/step - loss: 1.4706e-04
# Epoch 36/100
# 48/48 [==============================] - 1s 26ms/step - loss: 1.4088e-04
# Epoch 37/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.3923e-04
# Epoch 38/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3945e-04
# Epoch 39/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.4290e-04
# Epoch 40/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3599e-04
# Epoch 41/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3571e-04
# Epoch 42/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3635e-04
# Epoch 43/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3648e-04
# Epoch 44/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3564e-04
# Epoch 45/100
# 48/48 [==============================] - 1s 26ms/step - loss: 1.3731e-04
# Epoch 46/100
# 48/48 [==============================] - 1s 26ms/step - loss: 1.3945e-04
# Epoch 47/100
# 48/48 [==============================] - 1s 26ms/step - loss: 1.3763e-04
# Epoch 48/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.3591e-04
# Epoch 49/100
# 48/48 [==============================] - 1s 26ms/step - loss: 1.3669e-04
# Epoch 50/100
# 48/48 [==============================] - 1s 26ms/step - loss: 1.3861e-04
# Epoch 51/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.3701e-04
# Epoch 52/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.3540e-04
# Epoch 53/100
# 48/48 [==============================] - 1s 23ms/step - loss: 1.3955e-04
# Epoch 54/100
# 48/48 [==============================] - 1s 23ms/step - loss: 1.3892e-04
# Epoch 55/100
# 48/48 [==============================] - 1s 23ms/step - loss: 1.3680e-04
# Epoch 56/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3765e-04
# Epoch 57/100
# 48/48 [==============================] - 1s 23ms/step - loss: 1.3720e-04
# Epoch 58/100
# 48/48 [==============================] - 1s 27ms/step - loss: 1.3663e-04
# Epoch 59/100
# 48/48 [==============================] - 1s 28ms/step - loss: 1.3499e-04
# Epoch 60/100
# 48/48 [==============================] - 1s 26ms/step - loss: 1.3626e-04
# Epoch 61/100
# 48/48 [==============================] - 1s 26ms/step - loss: 1.3717e-04
# Epoch 62/100
# 48/48 [==============================] - 1s 26ms/step - loss: 1.3946e-04
# Epoch 63/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.3603e-04
# Epoch 64/100
# 48/48 [==============================] - 1s 26ms/step - loss: 1.3659e-04
# Epoch 65/100
# 48/48 [==============================] - 1s 26ms/step - loss: 1.3839e-04
# Epoch 66/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3507e-04
# Epoch 67/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3585e-04
# Epoch 68/100
# 48/48 [==============================] - 1s 23ms/step - loss: 1.3599e-04
# Epoch 69/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3763e-04
# Epoch 70/100
# 48/48 [==============================] - 1s 23ms/step - loss: 1.3682e-04
# Epoch 71/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.3801e-04
# Epoch 72/100
# 48/48 [==============================] - 1s 26ms/step - loss: 1.3511e-04
# Epoch 73/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.3597e-04
# Epoch 74/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.3469e-04
# Epoch 75/100
# 48/48 [==============================] - 1s 26ms/step - loss: 1.3797e-04
# Epoch 76/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.3628e-04
# Epoch 77/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.3465e-04
# Epoch 78/100
# 48/48 [==============================] - 1s 26ms/step - loss: 1.3501e-04
# Epoch 79/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3778e-04
# Epoch 80/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3636e-04
# Epoch 81/100
# 48/48 [==============================] - 1s 23ms/step - loss: 1.3964e-04
# Epoch 82/100
# 48/48 [==============================] - 1s 23ms/step - loss: 1.3479e-04
# Epoch 83/100
# 48/48 [==============================] - 1s 23ms/step - loss: 1.3739e-04
# Epoch 84/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3522e-04
# Epoch 85/100
# 48/48 [==============================] - 1s 27ms/step - loss: 1.3559e-04
# Epoch 86/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.3504e-04
# Epoch 87/100
# 48/48 [==============================] - 1s 26ms/step - loss: 1.4073e-04
# Epoch 88/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.3964e-04
# Epoch 89/100
# 48/48 [==============================] - 1s 26ms/step - loss: 1.3455e-04
# Epoch 90/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3521e-04
# Epoch 91/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3545e-04
# Epoch 92/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3475e-04
# Epoch 93/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3505e-04
# Epoch 94/100
# 48/48 [==============================] - 1s 23ms/step - loss: 1.3618e-04
# Epoch 95/100
# 48/48 [==============================] - 1s 23ms/step - loss: 1.3560e-04
# Epoch 96/100
# 48/48 [==============================] - 1s 23ms/step - loss: 1.3650e-04
# Epoch 97/100
# 48/48 [==============================] - 1s 23ms/step - loss: 1.3451e-04
# Epoch 98/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3447e-04
# Epoch 99/100
# 48/48 [==============================] - 1s 25ms/step - loss: 1.3442e-04
# Epoch 100/100
# 48/48 [==============================] - 1s 24ms/step - loss: 1.3582e-04

# %%
# Make predictions
y_pred = model.predict(X_test)
# Out:
# 11/11 [==============================] - 1s 13ms/step

# %%
y_pred
# Out:
# array([[-1.6814976e-03],
#        [-7.3213305e-04],
#        [ 6.9815898e-05],
#        [-7.2403485e-04],
#        [ 8.7904348e-04],
#        [-1.3543351e-03],
#        [ 2.1971413e-04],
#        [-1.0581200e-03],
#        [-2.6373444e-03],
#        [-4.9013400e-04],
#        [-1.6007088e-03],
#        [-3.7977006e-05],
#        [-8.5106306e-04],
#        [ 1.0942057e-03],
#        [ 3.1878322e-04],
#        [ 4.1549199e-04],
#        [ 7.1484526e-04],
#        [ 1.7930346e-03],
#        [ 4.0137838e-04],
#        [-8.2724530e-04],
#        [-2.6507557e-03],
#        [-9.1585482e-04],
#        [-1.4449554e-03],
#        [-2.1817575e-03],
#        [-2.9201817e-03],
#        [-2.1764960e-03],
#        [-2.0740114e-03],
#        [-2.2286857e-03],
#        [-2.2959115e-03],
#        [-9.6033025e-04],
#        [-1.2635642e-03],
#        [-1.2923847e-03],
#        [-8.3593116e-04],
#        [ 1.2387423e-03],
#        [-7.1647740e-04],
#        [ 3.1234673e-04],
#        [-5.0673750e-04],
#        [-3.2776268e-04],
#        [-3.3695181e-04],
#        [-2.5935005e-06],
#        [-7.5267744e-04],
#        [-5.5360608e-05],
#        [ 1.0492720e-03],
#        [-8.0586062e-04],
#        [-7.9075224e-04],
#        [-1.3540895e-04],
#        [-6.4468361e-04],
#        [-1.7601638e-03],
#        [-2.9043986e-03],
#        [-8.5815450e-04],
#        [-4.4188974e-04],
#        [-4.6299142e-04],
#        [-1.6829360e-03],
#        [-1.2278284e-03],
#        [-1.3890120e-03],
#        [-1.6196545e-03],
#        [-1.6365962e-03],
#        [-2.1107350e-03],
#        [-1.5490854e-03],
#        [ 1.5787885e-04],
#        [-9.0092397e-04],
#        [-4.3640472e-04],
#        [ 3.3866614e-05],
#        [-5.5805058e-04],
#        [-7.9877023e-04],
#        [-1.4820129e-03],
#        [-1.0616286e-04],
#        [-7.6366356e-05],
#        [ 3.1937589e-04],
#        [ 4.3409551e-04],
#        [-9.7222242e-04],
#        [-4.9320015e-04],
#        [ 5.4025359e-04],
#        [ 4.1751086e-04],
#        [-1.0605019e-03],
#        [-1.2440195e-03],
#        [-2.5412373e-03],
#        [-1.1140427e-03],
#        [-2.0748244e-03],
#        [-1.6377841e-03],
#        [-2.9554381e-04],
#        [-3.3259939e-04],
#        [-9.6450781e-04],
#        [ 1.0398065e-03],
#        [-4.5543909e-04],
#        [-1.5285476e-03],
#        [-9.8222005e-04],
#        [-7.0894696e-04],
#        [-1.4722482e-03],
#        [-4.2425701e-05],
#        [-1.1406101e-03],
#        [-2.5315266e-03],
#        [-2.5267121e-03],
#        [-1.6100171e-03],
#        [-5.2861008e-04],
#        [-7.3401059e-04],
#        [ 3.7517888e-04],
#        [ 1.7737132e-04],
#        [ 9.5879263e-04],
#        [ 5.3287647e-04],
#        [ 5.3333235e-04],
#        [ 4.7786534e-04],
#        [ 3.5890820e-04],
#        [-1.6891276e-03],
#        [-2.0358723e-03],
#        [-1.5531790e-03],
#        [-1.1021385e-03],
#        [-4.2037969e-04],
#        [-5.4055196e-04],
#        [-8.4614451e-04],
#        [-4.9472973e-04],
#        [-4.9812091e-04],
#        [-2.3938597e-03],
#        [-6.9338130e-05],
#        [-5.6536612e-04],
#        [-7.5816829e-04],
#        [-8.1271236e-04],
#        [-7.1202661e-04],
#        [-3.2380340e-04],
#        [ 4.0742289e-04],
#        [ 2.1880928e-03],
#        [ 3.5580602e-03],
#        [ 4.4533359e-03],
#        [ 2.2198893e-03],
#        [-3.6781880e-03],
#        [-3.7456371e-03],
#        [-1.5726385e-03],
#        [-6.1648642e-04],
#        [ 1.4458282e-03],
#        [-2.7807502e-03],
#        [-2.2756553e-03],
#        [-4.9552880e-05],
#        [-3.2805807e-03],
#        [-3.1609472e-04],
#        [-1.0565715e-03],
#        [-1.5361188e-03],
#        [-5.1950442e-04],
#        [-1.9131305e-03],
#        [-1.8883159e-03],
#        [-6.7574787e-04],
#        [ 1.1694480e-03],
#        [-6.5918884e-04],
#        [ 5.6880503e-04],
#        [-4.3568667e-05],
#        [-1.3830629e-04],
#        [-1.7903375e-03],
#        [ 2.3819366e-04],
#        [-1.0613508e-03],
#        [-2.5342384e-03],
#        [-1.1838696e-03],
#        [-1.9751678e-03],
#        [-3.1164039e-03],
#        [-1.6015263e-03],
#        [-2.1206257e-03],
#        [-2.0211001e-03],
#        [-1.3849253e-03],
#        [-1.1730401e-03],
#        [-7.1247166e-04],
#        [ 1.2519304e-06],
#        [-2.0249076e-03],
#        [-1.9671924e-03],
#        [-1.3819907e-03],
#        [-1.1725002e-03],
#        [-1.0412440e-03],
#        [-3.1509132e-03],
#        [-2.6554938e-03],
#        [-1.5537650e-03],
#        [-1.2132621e-03],
#        [-2.3644234e-03],
#        [-1.0915839e-03],
#        [-2.0006718e-04],
#        [-1.5059938e-03],
#        [-1.4564137e-03],
#        [-7.5627991e-04],
#        [-7.4215373e-04],
#        [-7.7828253e-04],
#        [ 4.7030230e-04],
#        [-4.2859302e-04],
#        [-6.3320552e-04],
#        [ 3.1756796e-04],
#        [ 5.6814775e-04],
#        [-2.0542159e-03],
#        [-1.4806399e-03],
#        [-2.8668216e-03],
#        [-1.6820163e-03],
#        [-2.3590417e-03],
#        [-1.8336370e-03],
#        [-2.2801477e-03],
#        [-1.6263684e-03],
#        [-1.1524565e-03],
#        [ 2.6738271e-05],
#        [-7.2578131e-04],
#        [ 1.0490231e-03],
#        [ 2.4140927e-03],
#        [-9.5830276e-04],
#        [ 6.3969754e-04],
#        [ 1.0012358e-03],
#        [ 2.1275482e-04],
#        [-1.3152997e-03],
#        [ 3.6392570e-04],
#        [-2.0660188e-03],
#        [-3.0036441e-03],
#        [-3.7060811e-03],
#        [-7.2701485e-04],
#        [ 1.1268661e-03],
#        [-1.2234452e-03],
#        [-2.0272885e-03],
#        [-2.4098223e-03],
#        [-1.1544211e-03],
#        [-1.1269276e-03],
#        [-2.4914625e-03],
#        [-1.0546299e-03],
#        [-5.5031246e-04],
#        [ 7.4461033e-04],
#        [-4.6699704e-04],
#        [ 8.5608312e-04],
#        [ 1.8919555e-03],
#        [ 5.0044642e-04],
#        [-1.1752897e-03],
#        [-2.0143555e-03],
#        [ 9.3302876e-04],
#        [-1.3582574e-03],
#        [ 2.1584316e-03],
#        [ 2.3742230e-04],
#        [ 1.2746144e-03],
#        [-5.9137389e-04],
#        [-1.3843758e-03],
#        [ 9.3383924e-04],
#        [-1.7542187e-03],
#        [ 7.9924078e-04],
#        [-1.6160689e-03],
#        [-3.8542359e-03],
#        [-1.7441164e-03],
#        [ 1.0765211e-03],
#        [-8.7704347e-04],
#        [-1.0500194e-03],
#        [ 5.8747688e-04],
#        [ 6.6859159e-04],
#        [-7.1396562e-04],
#        [-7.1938243e-04],
#        [ 6.8930676e-05],
#        [-3.7216649e-03],
#        [-3.7339248e-03],
#        [-3.5769918e-03],
#        [-1.5398697e-03],
#        [-1.3061268e-03],
#        [-2.9415798e-03],
#        [-9.0218137e-04],
#        [-1.5171971e-03],
#        [-2.4365007e-03],
#        [-9.5737772e-04],
#        [-3.4074089e-04],
#        [-3.4675596e-03],
#        [-2.4643124e-03],
#        [-2.2020421e-03],
#        [-2.1590355e-03],
#        [-2.5336130e-03],
#        [-1.0005429e-03],
#        [-1.3118505e-03],
#        [-8.6049899e-04],
#        [-2.1086887e-03],
#        [-1.4743439e-03],
#        [-1.2663442e-03],
#        [-1.6385387e-03],
#        [-1.6559802e-03],
#        [-1.1505710e-03],
#        [-5.7239714e-04],
#        [ 6.6897599e-05],
#        [ 2.0931452e-04],
#        [-5.6443946e-04],
#        [-1.1220740e-03],
#        [-1.9907427e-03],
#        [-2.0781069e-03],
#        [-1.4074538e-03],
#        [-1.9295078e-03],
#        [-1.0011510e-03],
#        [-4.0228874e-04],
#        [-1.7674542e-03],
#        [-3.9053173e-04],
#        [-1.2365798e-03],
#        [-1.1052052e-03],
#        [-1.9746218e-03],
#        [-2.2055421e-03],
#        [-1.4885755e-03],
#        [-1.3275780e-03],
#        [-2.0617719e-03],
#        [-1.9145606e-03],
#        [-2.0035987e-03],
#        [-1.1739724e-03],
#        [-1.4241911e-03],
#        [-8.8137039e-04],
#        [-1.1009779e-03],
#        [-1.5630254e-03],
#        [-3.5295426e-04],
#        [-8.0751046e-04],
#        [-1.8426899e-03],
#        [-9.3469664e-04],
#        [-5.4312660e-04],
#        [-1.0763763e-03],
#        [-1.7341322e-03],
#        [-1.5769550e-03],
#        [-2.5626232e-03],
#        [-4.4225086e-04],
#        [-7.3144073e-04],
#        [ 3.2234495e-04],
#        [-1.0325145e-03],
#        [ 6.9630030e-04],
#        [ 2.4645030e-04],
#        [ 6.8051787e-04],
#        [-2.6093656e-04],
#        [-1.1541764e-04],
#        [-1.7741590e-03],
#        [-1.7875421e-03],
#        [-1.1323027e-03],
#        [-1.4376298e-03],
#        [-1.0352994e-03],
#        [-1.2893595e-03],
#        [-1.5295253e-03],
#        [-1.5885530e-03],
#        [-2.0779655e-03],
#        [-1.6704204e-03],
#        [-1.6648171e-03],
#        [-9.2117034e-04],
#        [ 2.6716304e-04],
#        [ 8.3323033e-04],
#        [ 5.4166978e-04],
#        [ 2.1744310e-04],
#        [-9.0591027e-04],
#        [-5.9093558e-04],
#        [-1.8853021e-03],
#        [-1.7132994e-03],
#        [-2.0800626e-03],
#        [-3.5381869e-03],
#        [ 8.8238600e-04],
#        [ 1.1228113e-03],
#        [-1.4776115e-03],
#        [-1.8064997e-03],
#        [-1.7162901e-03]], dtype=float32)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
from math import sqrt

# Calculate the error metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)

print(f'MAE: {mae}')
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
# Out:
# MAE: 0.007444734122410704
# MSE: 9.812161782313781e-05
# RMSE: 0.009905635659721078

# %%
import matplotlib.pyplot as plt

# Plot the actual and predicted returns
plt.figure(figsize=(14, 5))
plt.plot(y_test, color='blue', label='Actual returns')
plt.plot(y_pred, color='red', label='Predicted returns')
plt.title('Stock returns prediction')
plt.xlabel('Time')
plt.ylabel('Normalized stock returns')
plt.legend()
plt.show()
